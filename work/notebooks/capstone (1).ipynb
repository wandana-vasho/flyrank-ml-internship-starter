# %% [markdown]
# # Capstone — mirrors your deployed research paper
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/capstone.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Question
#
# *The research question and the decision it supports.*

# %% [markdown]
# ## Demo Outline (5 minutes) — Week 8 Showcase
#
# 1. (30s) The question: can we predict which pages need a content refresh, using only search position and volume?
# 2. (60s) Show the baseline rule and its near-perfect score — then reveal the label-coupling issue that makes it misleading.
# 3. (90s) Show the honest model comparison (grouped split, leakage-checked) — f1≈0.82, genuinely generalizable.
# 4. (60s) Show the action playbook — three archetypes, real page counts, human-review-required.
# 5. (30s) Close on limitations and what I'd build next with more time (multi-month data, richer features).
#
# ## Shareable Cut — Social Post
#
# Built an ML pipeline on FlyRank's 79M-row search warehouse — and along the way, caught my own baseline cheating (it was too closely tied to my label). Ended up with an honest, leakage-checked model and a 735K-row action playbook, all documented end-to-end in my capstone.
#
# ## Shareable Cut — Employer-Facing Summary (3 sentences)
#
# I built and validated a search-content prioritization model using FlyRank's production search warehouse (79M+ rows), applying grouped client-level validation and a dedicated leakage audit to ensure honest results. Along the way, I identified and corrected a measurement flaw where my own baseline was too tightly coupled to my label definition — a finding I documented transparently rather than hiding. The final deliverable is a three-tier action playbook (735,691 ranked pages) with clear human-review rules, deployed as a public research paper with full reproducibility links.

# %% [markdown]
# ## 2. Data
#
# *Which release, which tables, date windows, what you excluded and why. Public-safe.*

# %% [markdown]
# ## Demo Outline (5 minutes) — Week 8 Showcase
#
# 1. (30s) The question: can we predict which pages need a content refresh, using only search position and volume?
# 2. (60s) Show the baseline rule and its near-perfect score — then reveal the label-coupling issue that makes it misleading.
# 3. (90s) Show the honest model comparison (grouped split, leakage-checked) — f1≈0.82, genuinely generalizable.
# 4. (60s) Show the action playbook — three archetypes, real page counts, human-review-required.
# 5. (30s) Close on limitations and what I'd build next with more time (multi-month data, richer features).
#
# ## Shareable Cut — Social Post
#
# Built an ML pipeline on FlyRank's 79M-row search warehouse — and along the way, caught my own baseline cheating (it was too closely tied to my label). Ended up with an honest, leakage-checked model and a 735K-row action playbook, all documented end-to-end in my capstone.
#
# ## Shareable Cut — Employer-Facing Summary (3 sentences)
#
# I built and validated a search-content prioritization model using FlyRank's production search warehouse (79M+ rows), applying grouped client-level validation and a dedicated leakage audit to ensure honest results. Along the way, I identified and corrected a measurement flaw where my own baseline was too tightly coupled to my label definition — a finding I documented transparently rather than hiding. The final deliverable is a three-tier action playbook (735,691 ranked pages) with clear human-review rules, deployed as a public research paper with full reproducibility links.

# %% [markdown]
# ## 3. Methodology
#
# *Assumptions, features, label definition, baseline, validation design, leakage checks.*

# %% [markdown]
# ## Demo Outline (5 minutes) — Week 8 Showcase
#
# 1. (30s) The question: can we predict which pages need a content refresh, using only search position and volume?
# 2. (60s) Show the baseline rule and its near-perfect score — then reveal the label-coupling issue that makes it misleading.
# 3. (90s) Show the honest model comparison (grouped split, leakage-checked) — f1≈0.82, genuinely generalizable.
# 4. (60s) Show the action playbook — three archetypes, real page counts, human-review-required.
# 5. (30s) Close on limitations and what I'd build next with more time (multi-month data, richer features).
#
# ## Shareable Cut — Social Post
#
# Built an ML pipeline on FlyRank's 79M-row search warehouse — and along the way, caught my own baseline cheating (it was too closely tied to my label). Ended up with an honest, leakage-checked model and a 735K-row action playbook, all documented end-to-end in my capstone.
#
# ## Shareable Cut — Employer-Facing Summary (3 sentences)
#
# I built and validated a search-content prioritization model using FlyRank's production search warehouse (79M+ rows), applying grouped client-level validation and a dedicated leakage audit to ensure honest results. Along the way, I identified and corrected a measurement flaw where my own baseline was too tightly coupled to my label definition — a finding I documented transparently rather than hiding. The final deliverable is a three-tier action playbook (735,691 ranked pages) with clear human-review rules, deployed as a public research paper with full reproducibility links.

# %% [markdown]
# ## 4. Results (vs baseline)
#
# *Model vs baseline on the same split. The honest table.*

# %% [markdown]
# ## Demo Outline (5 minutes) — Week 8 Showcase
#
# 1. (30s) The question: can we predict which pages need a content refresh, using only search position and volume?
# 2. (60s) Show the baseline rule and its near-perfect score — then reveal the label-coupling issue that makes it misleading.
# 3. (90s) Show the honest model comparison (grouped split, leakage-checked) — f1≈0.82, genuinely generalizable.
# 4. (60s) Show the action playbook — three archetypes, real page counts, human-review-required.
# 5. (30s) Close on limitations and what I'd build next with more time (multi-month data, richer features).
#
# ## Shareable Cut — Social Post
#
# Built an ML pipeline on FlyRank's 79M-row search warehouse — and along the way, caught my own baseline cheating (it was too closely tied to my label). Ended up with an honest, leakage-checked model and a 735K-row action playbook, all documented end-to-end in my capstone.
#
# ## Shareable Cut — Employer-Facing Summary (3 sentences)
#
# I built and validated a search-content prioritization model using FlyRank's production search warehouse (79M+ rows), applying grouped client-level validation and a dedicated leakage audit to ensure honest results. Along the way, I identified and corrected a measurement flaw where my own baseline was too tightly coupled to my label definition — a finding I documented transparently rather than hiding. The final deliverable is a three-tier action playbook (735,691 ranked pages) with clear human-review rules, deployed as a public research paper with full reproducibility links.

# %% [markdown]
# ## 5. Limitations
#
# *What this work cannot claim.*

# %% [markdown]
# ## Demo Outline (5 minutes) — Week 8 Showcase
#
# 1. (30s) The question: can we predict which pages need a content refresh, using only search position and volume?
# 2. (60s) Show the baseline rule and its near-perfect score — then reveal the label-coupling issue that makes it misleading.
# 3. (90s) Show the honest model comparison (grouped split, leakage-checked) — f1≈0.82, genuinely generalizable.
# 4. (60s) Show the action playbook — three archetypes, real page counts, human-review-required.
# 5. (30s) Close on limitations and what I'd build next with more time (multi-month data, richer features).
#
# ## Shareable Cut — Social Post
#
# Built an ML pipeline on FlyRank's 79M-row search warehouse — and along the way, caught my own baseline cheating (it was too closely tied to my label). Ended up with an honest, leakage-checked model and a 735K-row action playbook, all documented end-to-end in my capstone.
#
# ## Shareable Cut — Employer-Facing Summary (3 sentences)
#
# I built and validated a search-content prioritization model using FlyRank's production search warehouse (79M+ rows), applying grouped client-level validation and a dedicated leakage audit to ensure honest results. Along the way, I identified and corrected a measurement flaw where my own baseline was too tightly coupled to my label definition — a finding I documented transparently rather than hiding. The final deliverable is a three-tier action playbook (735,691 ranked pages) with clear human-review rules, deployed as a public research paper with full reproducibility links.

# %% [markdown]
# ## 6. Ranked recommendations
#
# *The action playbook output — the paper's recommendations section.*

# %% [markdown]
# ## Demo Outline (5 minutes) — Week 8 Showcase
#
# 1. (30s) The question: can we predict which pages need a content refresh, using only search position and volume?
# 2. (60s) Show the baseline rule and its near-perfect score — then reveal the label-coupling issue that makes it misleading.
# 3. (90s) Show the honest model comparison (grouped split, leakage-checked) — f1≈0.82, genuinely generalizable.
# 4. (60s) Show the action playbook — three archetypes, real page counts, human-review-required.
# 5. (30s) Close on limitations and what I'd build next with more time (multi-month data, richer features).
#
# ## Shareable Cut — Social Post
#
# Built an ML pipeline on FlyRank's 79M-row search warehouse — and along the way, caught my own baseline cheating (it was too closely tied to my label). Ended up with an honest, leakage-checked model and a 735K-row action playbook, all documented end-to-end in my capstone.
#
# ## Shareable Cut — Employer-Facing Summary (3 sentences)
#
# I built and validated a search-content prioritization model using FlyRank's production search warehouse (79M+ rows), applying grouped client-level validation and a dedicated leakage audit to ensure honest results. Along the way, I identified and corrected a measurement flaw where my own baseline was too tightly coupled to my label definition — a finding I documented transparently rather than hiding. The final deliverable is a three-tier action playbook (735,691 ranked pages) with clear human-review rules, deployed as a public research paper with full reproducibility links.

# %% [markdown]
# ## 7. Artifacts the paper embeds
#
# *Generate/collect the charts and tables your deployed page will show.*

# %% [markdown]
# ## Demo Outline (5 minutes) — Week 8 Showcase
#
# 1. (30s) The question: can we predict which pages need a content refresh, using only search position and volume?
# 2. (60s) Show the baseline rule and its near-perfect score — then reveal the label-coupling issue that makes it misleading.
# 3. (90s) Show the honest model comparison (grouped split, leakage-checked) — f1≈0.82, genuinely generalizable.
# 4. (60s) Show the action playbook — three archetypes, real page counts, human-review-required.
# 5. (30s) Close on limitations and what I'd build next with more time (multi-month data, richer features).
#
# ## Shareable Cut — Social Post
#
# Built an ML pipeline on FlyRank's 79M-row search warehouse — and along the way, caught my own baseline cheating (it was too closely tied to my label). Ended up with an honest, leakage-checked model and a 735K-row action playbook, all documented end-to-end in my capstone.
#
# ## Shareable Cut — Employer-Facing Summary (3 sentences)
#
# I built and validated a search-content prioritization model using FlyRank's production search warehouse (79M+ rows), applying grouped client-level validation and a dedicated leakage audit to ensure honest results. Along the way, I identified and corrected a measurement flaw where my own baseline was too tightly coupled to my label definition — a finding I documented transparently rather than hiding. The final deliverable is a three-tier action playbook (735,691 ranked pages) with clear human-review rules, deployed as a public research paper with full reproducibility links.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
# - [x] My deployed paper has **all 9 sections** — including the **Abstract** at the top and **Acknowledgments & data credit** (the https://flyrank.ai link) at the bottom.
# - [x] **ML-12 done in this notebook's closing cells:** 5-minute demo outline + a social-post cut + a 3-sentence employer-facing summary.
